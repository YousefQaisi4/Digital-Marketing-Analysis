# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('digitalmarketing.csv')
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1023 entries, 0 to 1022
# Data columns (total 48 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Authors                        1023 non-null   object
#  1   Author(s) ID                   1022 non-null   object
#  2   Title                          1023 non-null   object
#  3   Year                           1023 non-null   int64
#  4   Source title                   1023 non-null   object
#  5   Volume                         782 non-null    object
#  6   Issue                          604 non-null    object
#  7   Art. No.                       148 non-null    object
#  8   Page start                     878 non-null    object
#  9   Page end                       871 non-null    object
#  10  Page count                     18 non-null     float64
#  11  Cited by                       540 non-null    float64
#  12  DOI                            755 non-null    object
#  13  Link                           1023 non-null   object
#  14  Affiliations                   934 non-null    object
#  15  Authors with affiliations      1004 non-null   object
#  16  Abstract                       1023 non-null   object
#  17  Author Keywords                800 non-null    object
#  18  Index Keywords                 391 non-null    object
#  19  Molecular Sequence Numbers     0 non-null      float64
#  20  Chemicals/CAS                  2 non-null      object
#  21  Tradenames                     0 non-null      float64
#  22  Manufacturers                  0 non-null      float64
#  23  Funding Details                87 non-null     object
#  24  Funding Text 1                 113 non-null    object
#  25  Funding Text 2                 6 non-null      object
#  26  Funding Text 3                 1 non-null      object
#  27  References                     890 non-null    object
#  28  Correspondence Address         667 non-null    object
#  29  Editors                        166 non-null    object
#  30  Sponsors                       88 non-null     object
#  31  Publisher                      893 non-null    object
#  32  Conference name                280 non-null    object
#  33  Conference date                280 non-null    object
#  34  Conference location            24 non-null     object
#  35  Conference code                280 non-null    float64
#  36  ISSN                           793 non-null    object
#  37  ISBN                           313 non-null    object
#  38  CODEN                          82 non-null     object
#  39  PubMed ID                      30 non-null     float64
#  40  Language of Original Document  1021 non-null   object
#  41  Abbreviated Source Title       1008 non-null   object
#  42  Document Type                  1023 non-null   object
#  43  Publication Stage              1023 non-null   object
#  44  Access Type                    183 non-null    object
#  45  Source                         1023 non-null   object
#  46  EID                            1023 non-null   object
#  47  Citation_Level (TARGET)        1023 non-null   object
# dtypes: float64(7), int64(1), object(40)
# memory usage: 383.8+ KB

# %%
print(df.dtypes)
# Out:
# Authors                           object
# Author(s) ID                      object
# Title                             object
# Year                               int64
# Source title                      object
# Volume                            object
# Issue                             object
# Art. No.                          object
# Page start                        object
# Page end                          object
# Page count                       float64
# Cited by                         float64
# DOI                               object
# Link                              object
# Affiliations                      object
# Authors with affiliations         object
# Abstract                          object
# Author Keywords                   object
# Index Keywords                    object
# Molecular Sequence Numbers       float64
# Chemicals/CAS                     object
# Tradenames                       float64
# Manufacturers                    float64
# Funding Details                   object
# Funding Text 1                    object
# Funding Text 2                    object
# Funding Text 3                    object
# References                        object
# Correspondence Address            object
# Editors                           object
# Sponsors                          object
# Publisher                         object
# Conference name                   object
# Conference date                   object
# Conference location               object
# Conference code                  float64
# ISSN                              object
# ISBN                              object
# CODEN                             object
# PubMed ID                        float64
# Language of Original Document     object
# Abbreviated Source Title          object
# Document Type                     object
# Publication Stage                 object
# Access Type                       object
# Source                            object
# EID                               object
# Citation_Level (TARGET)           object
# dtype: object

# %%
df.describe()
# Out:
#               Year   Page count    Cited by  Molecular Sequence Numbers  \
# count  1023.000000    18.000000  540.000000                         0.0
# mean   2016.318671   333.722222   11.820370                         NaN
# std       3.526821   415.513687   29.678974                         NaN
# min    1982.000000     4.000000    1.000000                         NaN
# 25%    2015.000000    16.000000    1.000000                         NaN
# 50%    2017.000000   128.000000    3.000000                         NaN
# 75%    2019.000000   492.000000    9.000000                         NaN
# max    2019.000000  1272.000000  350.000000                         NaN
#
#        Tradenames  Manufacturers  Conference code     PubMed ID
# count         0.0            0.0       280.000000  3.000000e+01
# mean          NaN            NaN    149633.135714  2.790217e+07
# std           NaN            NaN     36683.181803  2.811333e+06
# min           NaN            NaN     70552.000000  2.264317e+07
# 25%           NaN            NaN    126589.000000  2.547778e+07
# 50%           NaN            NaN    144531.000000  2.820805e+07
# 75%           NaN            NaN    157139.000000  3.035248e+07
# max           NaN            NaN    239599.000000  3.166614e+07

# %%
print(df.isnull().sum())
df.fillna(df.mean(numeric_only=True) , inplace=True)
for columns in df.columns:
  if df[columns].dtype == 'object':
    df[columns].fillna(df[columns].mode()[0], inplace=True)
# Out:
# Authors                             0
# Author(s) ID                        1
# Title                               0
# Year                                0
# Source title                        0
# Volume                            241
# Issue                             419
# Art. No.                          875
# Page start                        145
# Page end                          152
# Page count                       1005
# Cited by                          483
# DOI                               268
# Link                                0
# Affiliations                       89
# Authors with affiliations          19
# Abstract                            0
# Author Keywords                   223
# Index Keywords                    632
# Molecular Sequence Numbers       1023
# Chemicals/CAS                    1021
# Tradenames                       1023
# Manufacturers                    1023
# Funding Details                   936
# Funding Text 1                    910
# Funding Text 2                   1017
# Funding Text 3                   1022
# References                        133
# Correspondence Address            356
# Editors                           857
# Sponsors                          935
# Publisher                         130
# Conference name                   743
# Conference date                   743
# Conference location               999
# Conference code                   743
# ISSN                              230
# ISBN                              710
# CODEN                             941
# PubMed ID                         993
# Language of Original Document       2
# Abbreviated Source Title           15
# Document Type                       0
# Publication Stage                   0
# Access Type                       840
# Source                              0
# EID                                 0
# Citation_Level (TARGET)             0
# dtype: int64
# /tmp/ipykernel_15006/218345269.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[columns].fillna(df[columns].mode()[0], inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("digitalmarketing.csv")

df.hist(figsize=(15,10), bins=10, edgecolor='black')
plt.tight_layout()
plt.show()
